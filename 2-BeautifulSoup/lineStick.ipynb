# %%
# Out:
# <ul class="mdCMN09Ul FnStickerList">
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024969", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024969/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024969/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024969/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024969/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024970", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024970/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024970/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024970/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024970/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024971", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024971/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024971/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024971/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024971/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024972", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024972/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024972/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024972/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024972/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024973", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024973/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024973/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024973/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024973/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024974", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024974/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024974/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024974/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024974/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024975", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024975/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024975/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024975/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024975/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024976", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024976/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024976/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024976/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024976/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024977", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024977/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024977/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024977/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024977/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024978", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024978/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024978/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024978/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024978/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024979", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024979/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024979/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024979/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024979/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024980", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024980/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024980/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024980/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024980/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024981", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024981/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024981/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024981/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024981/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024982", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024982/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024982/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024982/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024982/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024983", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024983/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024983/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024983/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024983/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024984", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024984/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024984/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024984/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024984/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024985", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024985/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024985/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024985/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024985/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024986", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024986/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024986/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024986/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024986/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024987", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024987/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024987/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024987/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024987/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024988", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024988/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024988/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024988/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024988/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024989", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024989/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024989/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024989/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024989/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024990", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024990/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024990/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024990/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024990/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024991", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024991/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024991/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024991/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024991/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024992", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024992/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024992/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024992/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024992/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024993", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024993/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024993/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024993/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024993/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024994", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024994/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024994/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024994/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024994/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024995", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024995/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024995/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024995/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024995/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024996", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024996/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024996/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024996/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024996/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024997", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024997/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024997/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024997/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024997/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024998", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024998/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024998/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024998/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024998/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798024999", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024999/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798024999/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024999/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798024999/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798025000", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798025000/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798025000/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798025000/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798025000/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798025001", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798025001/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798025001/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798025001/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798025001/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798025002", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798025002/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798025002/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798025002/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798025002/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798025003", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798025003/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798025003/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798025003/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798025003/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798025004", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798025004/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798025004/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798025004/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798025004/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798025005", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798025005/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798025005/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798025005/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798025005/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798025006", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798025006/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798025006/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798025006/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798025006/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798025007", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798025007/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798025007/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798025007/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798025007/android/sticker.png?v=1);"></span>
# </div>
# </li>
# <li class="mdCMN09Li FnStickerPreviewItem static-sticker" data-preview='{ "type" : "static", "id" : "798025008", "staticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798025008/android/sticker.png?v=1", "fallbackStaticUrl" : "https://stickershop.line-scdn.net/stickershop/v1/sticker/798025008/android/sticker.png?v=1", "animationUrl" : "", "popupUrl" : "", "soundUrl" : "" }' data-test="sticker-item">
# <div class="mdCMN09LiInner FnImage">
# <span class="mdCMN09Image" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798025008/android/sticker.png?v=1);"></span>
# </div>
# <div class="mdCMN09ImgPreview FnPreviewImage MdNonDisp">
# <span class="mdCMN09Image FnPreview" style="background-image:url(https://stickershop.line-scdn.net/stickershop/v1/sticker/798025008/android/sticker.png?v=1);"></span>
# </div>
# </li>
# </ul>

# %%
import os 
folder_name ="line_stickers"
print(os.path.exists(folder_name))
# 建立資料夾
if not os.path.exists(folder_name):
    os.mkdir("line_stickers")
else:
    print('資料夾{folder_name}已存在')
# Out:
# True

# %%
import json
import requests
from bs4 import BeautifulSoup as bs
import os 
folder_name ="line_stickers"
print(os.path.exists(folder_name))
# 建立資料夾
if not os.path.exists(folder_name):
    os.mkdir("line_stickers")
else:
    print(f'資料夾{folder_name}已存在')


url = f"https://store.line.me/stickershop/product/36271/zh-Hant"

r = requests.get(url)

soup = bs(r.text, "lxml")

# 找到貼圖清單
sticker_list = soup.find("ul", class_="mdCMN09Ul FnStickerList")
# print(sticker_list)
# 找到所有貼圖元素
sticker_elements =sticker_list.find_all('li')

# print(len(sticker_elements))
# Out:
# True
# 資料夾line_stickers已存在

# %%
for index, sticker_element in enumerate(sticker_elements, start=1):
    # print(sticker_element)
    # print(sticker_element["data-preview"])
    data_preview = json.loads(sticker_element["data-preview"])
    static_url = data_preview["staticUrl"]
    # print(static_url)

    image_content = requests.get(static_url).content
    with open(f"line_stickers/line_sticker_{index}.png", 'wb') as f:
        f.write(image_content)

    break
